# %%
import pandas as pd
import numpy as np
import scipy.stats as sp
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets.species_distributions import construct_grids
from sklearn.datasets import fetch_species_distributions
from sklearn.cluster import KMeans
from matplotlib import style
style.use("ggplot")
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-2edc6cace5ef> in <module>()
#       9 from matplotlib import style
#      10 style.use("ggplot")
# ---> 11 from mpl_toolkits.basemap import Basemap
#      12
#      13
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
dt = pd.read_csv("globalterrorismd.csv", encoding ='latin1')
dt.head()
# Out:
# C:\Users\Luigi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (4,6,31,33,53,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region   ...    addnotes scite1 scite2  scite3  \
# 0  Dominican Republic       2   ...         NaN    NaN    NaN     NaN
# 1              Mexico       1   ...         NaN    NaN    NaN     NaN
# 2         Philippines       5   ...         NaN    NaN    NaN     NaN
# 3              Greece       8   ...         NaN    NaN    NaN     NaN
# 4               Japan       4   ...         NaN    NaN    NaN     NaN
#
#    dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      PGIS        0         0        0       0      NaN
# 1      PGIS        0         1        1       1      NaN
# 2      PGIS       -9        -9        1       1      NaN
# 3      PGIS       -9        -9        1       1      NaN
# 4      PGIS       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
dt.region_txt.value_counts()
# Out:
# Middle East & North Africa     46511
# South Asia                     41497
# South America                  18762
# Western Europe                 16307
# Sub-Saharan Africa             15491
# Southeast Asia                 11453
# Central America & Caribbean    10340
# Eastern Europe                  5031
# North America                   3346
# East Asia                        794
# Central Asia                     554
# Australasia & Oceania            264
# Name: region_txt, dtype: int64

# %%
dt = dt.loc[:, ['iyear','imonth','iday','country','gname',
'country_txt',
'region_txt',
'region',
'city',
'latitude',
'longitude',
'success',
'attacktype1',
'attacktype1_txt',
'targtype1',
'targtype1_txt',
'targsubtype1',
'targsubtype1_txt',
 'weaptype1',
 'weaptype1_txt',
 'weapsubtype1',
 'weapsubtype1_txt',
 'weaptype2',
 'weaptype2_txt',
 'weapsubtype2',
 'weapsubtype2_txt',
 'nkill',
 'nwound',]]
dt= dt[(dt.region_txt=="Eastern Europe")|(dt.region_txt=="Western Europe")]
dt.nkill = dt.nkill.fillna(0)
dt.nwound = dt.nwound.fillna(0)

# %%
dt.head()
# Out:
#     iyear  imonth  iday  country  \
# 3    1970       1     0       78
# 12   1970       1     8       98
# 15   1970       1    10      499
# 34   1970       1    28      499
# 59   1970       2    10      362
#
#                                                 gname         country_txt  \
# 3                                             Unknown              Greece
# 12                                            Unknown               Italy
# 15                                          Commune 1  East Germany (GDR)
# 34                                            Unknown  East Germany (GDR)
# 59  Popular Front for the Liberation of Palestine ...  West Germany (FRG)
#
#         region_txt  region         city   latitude  ...    weaptype1  \
# 3   Western Europe       8       Athens  37.983773  ...            6
# 12  Western Europe       8         Rome  41.890520  ...            5
# 15  Eastern Europe       9  East Berlin  52.516667  ...            6
# 34  Eastern Europe       9  East Berlin  52.516667  ...            8
# 59  Western Europe       8       Munich  48.139126  ...            5
#
#                 weaptype1_txt  weapsubtype1               weapsubtype1_txt  \
# 3   Explosives/Bombs/Dynamite          16.0         Unknown Explosive Type
# 12                   Firearms           4.0  Rifle/Shotgun (non-automatic)
# 15  Explosives/Bombs/Dynamite          16.0         Unknown Explosive Type
# 34                 Incendiary          19.0   Molotov Cocktail/Petrol Bomb
# 59                   Firearms           2.0               Automatic Weapon
#
#     weaptype2 weaptype2_txt  weapsubtype2 weapsubtype2_txt  nkill nwound
# 3         NaN           NaN           NaN              NaN    0.0    0.0
# 12        5.0      Firearms           3.0          Handgun    0.0    0.0
# 15        NaN           NaN           NaN              NaN    0.0    0.0
# 34        NaN           NaN           NaN              NaN    0.0    0.0
# 59        NaN           NaN           NaN              NaN    1.0    0.0
#
# [5 rows x 28 columns]

# %%
dt.plot.scatter('nwound','nkill')
plt.show()

# %%
a = dt.nwound.cov(dt.nkill) / dt.nwound.var()
b = dt.nkill.mean() - a*dt.nwound.mean()

print('Ajuste linear entre nwound nkill:')
print('Coeficiente linear:', b)
print('Coeficiente angular:', a)

fig = plt.figure(figsize=(8, 6))
plt.scatter(dt.nwound, dt.nkill, c='red', alpha=0.8)
plt.title('nwound versus nkill')
plt.xlabel('wound')
plt.ylabel('kill')

plt.plot((dt.nwound.min(), dt.nwound.max()), (a*dt.nwound.min()+b, a*dt.nwound.max()+b), color='blue')
#axes = plt.gca()
#axes.set_xlim([0,200])
#axes.set_ylim([0,200])
plt.tight_layout()
plt.show()
print(dt.nwound.corr(dt.nkill))
# Out:
# Ajuste linear entre nwound nkill:
# Coeficiente linear: 0.368347295741
# Coeficiente angular: 0.20445710143
# 0.454097734617

# %%
m = Basemap(projection="cyl",
           llcrnrlat=13.00,
           llcrnrlon=-19.66,
           urcrnrlat=69.71,
           urcrnrlon = 72.61,
           resolution='l')
#Coordenadas em latitude e longitude
coordenadas = {
    "IRAQUE" : [33.3,43.35],
    "Portugal": [38.4,9.8],
    "Espanha" : [41.23,2.9],
    "Franca" : [48.51,2.20],
    "Italia" : [43.76,11.25]
}
IRAQlat,IRAQlon = 33.3,43.55
xpt,ypt = m(IRAQlon,IRAQlat)
m.plot(xpt,ypt,'co',markersize=30)
m.drawcoastlines()
m.drawcountries(linewidth=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-22eba7966563> in <module>()
# ----> 1 m = Basemap(projection="cyl",
#       2            llcrnrlat=13.00,
#       3            llcrnrlon=-19.66,
#       4            urcrnrlat=69.71,
#       5            urcrnrlon = 72.61,
#
# NameError: name 'Basemap' is not defined

# %%
dt_weap = dt.loc[:,['weaptype1_txt','nkill','nwound']]
dt_weap.nkill.groupby(dt.weaptype1_txt).mean()
dt_weap2 = pd.DataFrame(dt_weap.groupby(dt.weaptype1_txt).mean())
dt_weap2.plot(kind = 'bar', figsize = (10,5))
plt.title("media de mortos e feridos por tipo de arma")
plt.show()

# %%
dt_target = dt.loc[:,['targtype1_txt','nkill','nwound']]
dt_target2 = pd.DataFrame(dt_target.groupby(dt.targtype1_txt).mean())
dt_target2.plot(kind = 'bar', figsize= (20,8))
plt.title("media de mortos e feridos por tipo de ataque terrorista")
plt.show()

# %%
dt_attack = dt.loc[:,['attacktype1_txt','nkill','nwound']]
dt_attack2 = pd.DataFrame(dt_attack.groupby(dt.attacktype1_txt).mean())
dt_attack2.plot(kind = 'bar', figsize= (20,8))
plt.title("media de mortos e feridos por tipo de ataque terrorista")
plt.show()

# %%
x = []
y = []

plt.scatter(x,y)


X = np.array([])
kmeans = KMeans(n_clusters = 6)
kmeans.fit(X)

centroids = kmeans.cluster_centers_
labels = kmeans.labels_
colors = ["g.","r.","c.","y."]


for i in range(len(X)):
    print("coordinate:",X[i],"label:",labels[i])
    plt.plot(X[i][0],X[i][1],colors[labels[i]],markersize = 10)
    
plt.scatter(centrois[:,0],centroids[:,1],marker = "x",s = 150, linewidths = 5,zorder = 10)
plt.show()

# %%
ataques = []
for i in dt.attacktype1_txt:
    if i not in ataques:
        ataques.append(i)

paises = []
for i in dt.country_txt:
    if i not in paises:
        paises.append(i)
paises
# Out:
# ['Greece',
#  'Italy',
#  'East Germany (GDR)',
#  'West Germany (FRG)',
#  'Switzerland',
#  'Spain',
#  'Ireland',
#  'United Kingdom',
#  'Netherlands',
#  'Belgium',
#  'Sweden',
#  'Austria',
#  'Czechoslovakia',
#  'France',
#  'Cyprus',
#  'Yugoslavia',
#  'Portugal',
#  'Andorra',
#  'Malta',
#  'Soviet Union',
#  'Denmark',
#  'Norway',
#  'Poland',
#  'Vatican City',
#  'Albania',
#  'Bulgaria',
#  'Luxembourg',
#  'Iceland',
#  'Romania',
#  'Finland',
#  'Hungary',
#  'Germany',
#  'Croatia',
#  'Lithuania',
#  'Ukraine',
#  'Moldova',
#  'Russia',
#  'Bosnia-Herzegovina',
#  'Latvia',
#  'Estonia',
#  'Slovak Republic',
#  'Macedonia',
#  'Belarus',
#  'Czech Republic',
#  'Slovenia',
#  'Kosovo',
#  'Montenegro',
#  'Serbia-Montenegro',
#  'Serbia']

# %%
def bayes_attack(x,y):
        dt_novo = dt[dt.attacktype1_txt == y]
        total = len(dt_novo)
        P = len(dt_novo[dt_novo.country_txt == x])/total
        return P

# %%
dict = {}
for i in ataques:
    for k in paises:
        ind = 'P({0}|{1})'.format(k,i)
        P = bayes_attack(k,i)
        #print('P({0}|{1}) = {2}'.format(k,i,P)
        dict[ind] = bayes_attack(k,i)
dict
# Out:
# {'P(Albania|Armed Assault)': 0.0037787701820680177,
#  'P(Albania|Assassination)': 0.004248861911987861,
#  'P(Albania|Bombing/Explosion)': 0.004217516152189519,
#  'P(Albania|Facility/Infrastructure Attack)': 0.0003633720930232558,
#  'P(Albania|Hijacking)': 0.0,
#  'P(Albania|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Albania|Hostage Taking (Kidnapping))': 0.004123711340206186,
#  'P(Albania|Unarmed Assault)': 0.01092896174863388,
#  'P(Albania|Unknown)': 0.005361930294906166,
#  'P(Andorra|Armed Assault)': 0.00034352456200618345,
#  'P(Andorra|Assassination)': 0.0,
#  'P(Andorra|Bombing/Explosion)': 0.0,
#  'P(Andorra|Facility/Infrastructure Attack)': 0.0,
#  'P(Andorra|Hijacking)': 0.0,
#  'P(Andorra|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Andorra|Hostage Taking (Kidnapping))': 0.0,
#  'P(Andorra|Unarmed Assault)': 0.0,
#  'P(Andorra|Unknown)': 0.0,
#  'P(Austria|Armed Assault)': 0.0034352456200618343,
#  'P(Austria|Assassination)': 0.002731411229135053,
#  'P(Austria|Bombing/Explosion)': 0.004845656855707107,
#  'P(Austria|Facility/Infrastructure Attack)': 0.00944767441860465,
#  'P(Austria|Hijacking)': 0.02247191011235955,
#  'P(Austria|Hostage Taking (Barricade Incident))': 0.009433962264150943,
#  'P(Austria|Hostage Taking (Kidnapping))': 0.004123711340206186,
#  'P(Austria|Unarmed Assault)': 0.01092896174863388,
#  'P(Austria|Unknown)': 0.00804289544235925,
#  'P(Belarus|Armed Assault)': 0.00034352456200618345,
#  'P(Belarus|Assassination)': 0.0,
#  'P(Belarus|Bombing/Explosion)': 0.0007178750897343862,
#  'P(Belarus|Facility/Infrastructure Attack)': 0.0010901162790697674,
#  'P(Belarus|Hijacking)': 0.0,
#  'P(Belarus|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Belarus|Hostage Taking (Kidnapping))': 0.0,
#  'P(Belarus|Unarmed Assault)': 0.00546448087431694,
#  'P(Belarus|Unknown)': 0.0,
#  'P(Belgium|Armed Assault)': 0.0048093438680865686,
#  'P(Belgium|Assassination)': 0.006373292867981791,
#  'P(Belgium|Bombing/Explosion)': 0.005832735104091888,
#  'P(Belgium|Facility/Infrastructure Attack)': 0.00872093023255814,
#  'P(Belgium|Hijacking)': 0.011235955056179775,
#  'P(Belgium|Hostage Taking (Barricade Incident))': 0.009433962264150943,
#  'P(Belgium|Hostage Taking (Kidnapping))': 0.008247422680412371,
#  'P(Belgium|Unarmed Assault)': 0.06557377049180328,
#  'P(Belgium|Unknown)': 0.0160857908847185,
#  'P(Bosnia-Herzegovina|Armed Assault)': 0.010649261422191686,
#  'P(Bosnia-Herzegovina|Assassination)': 0.003338391502276176,
#  'P(Bosnia-Herzegovina|Bombing/Explosion)': 0.00933237616654702,
#  'P(Bosnia-Herzegovina|Facility/Infrastructure Attack)': 0.002180232558139535,
#  'P(Bosnia-Herzegovina|Hijacking)': 0.0,
#  'P(Bosnia-Herzegovina|Hostage Taking (Barricade Incident))': 0.009433962264150943,
#  'P(Bosnia-Herzegovina|Hostage Taking (Kidnapping))': 0.002061855670103093,
#  'P(Bosnia-Herzegovina|Unarmed Assault)': 0.01639344262295082,
#  'P(Bosnia-Herzegovina|Unknown)': 0.005361930294906166,
#  'P(Bulgaria|Armed Assault)': 0.0,
#  'P(Bulgaria|Assassination)': 0.002731411229135053,
#  'P(Bulgaria|Bombing/Explosion)': 0.002871500358937545,
#  'P(Bulgaria|Facility/Infrastructure Attack)': 0.0014534883720930232,
#  'P(Bulgaria|Hijacking)': 0.011235955056179775,
#  'P(Bulgaria|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Bulgaria|Hostage Taking (Kidnapping))': 0.002061855670103093,
#  'P(Bulgaria|Unarmed Assault)': 0.02185792349726776,
#  'P(Bulgaria|Unknown)': 0.002680965147453083,
#  'P(Croatia|Armed Assault)': 0.004465819306080384,
#  'P(Croatia|Assassination)': 0.0006069802731411229,
#  'P(Croatia|Bombing/Explosion)': 0.003679109834888729,
#  'P(Croatia|Facility/Infrastructure Attack)': 0.0,
#  'P(Croatia|Hijacking)': 0.0,
#  'P(Croatia|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Croatia|Hostage Taking (Kidnapping))': 0.0,
#  'P(Croatia|Unarmed Assault)': 0.0,
#  'P(Croatia|Unknown)': 0.002680965147453083,
#  'P(Cyprus|Armed Assault)': 0.0027481964960494676,
#  'P(Cyprus|Assassination)': 0.00819423368740516,
#  'P(Cyprus|Bombing/Explosion)': 0.008076094759511845,
#  'P(Cyprus|Facility/Infrastructure Attack)': 0.0010901162790697674,
#  'P(Cyprus|Hijacking)': 0.02247191011235955,
#  'P(Cyprus|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Cyprus|Hostage Taking (Kidnapping))': 0.004123711340206186,
#  'P(Cyprus|Unarmed Assault)': 0.0,
#  'P(Cyprus|Unknown)': 0.0,
#  'P(Czech Republic|Armed Assault)': 0.00034352456200618345,
#  'P(Czech Republic|Assassination)': 0.0009104704097116844,
#  'P(Czech Republic|Bombing/Explosion)': 0.0010768126346015793,
#  'P(Czech Republic|Facility/Infrastructure Attack)': 0.0029069767441860465,
#  'P(Czech Republic|Hijacking)': 0.0,
#  'P(Czech Republic|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Czech Republic|Hostage Taking (Kidnapping))': 0.0,
#  'P(Czech Republic|Unarmed Assault)': 0.0273224043715847,
#  'P(Czech Republic|Unknown)': 0.0,
#  'P(Czechoslovakia|Armed Assault)': 0.0,
#  'P(Czechoslovakia|Assassination)': 0.0006069802731411229,
#  'P(Czechoslovakia|Bombing/Explosion)': 0.0003589375448671931,
#  'P(Czechoslovakia|Facility/Infrastructure Attack)': 0.0,
#  'P(Czechoslovakia|Hijacking)': 0.02247191011235955,
#  'P(Czechoslovakia|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Czechoslovakia|Hostage Taking (Kidnapping))': 0.0,
#  'P(Czechoslovakia|Unarmed Assault)': 0.0,
#  'P(Czechoslovakia|Unknown)': 0.005361930294906166,
#  'P(Denmark|Armed Assault)': 0.0013740982480247338,
#  'P(Denmark|Assassination)': 0.0006069802731411229,
#  'P(Denmark|Bombing/Explosion)': 0.0015254845656855708,
#  'P(Denmark|Facility/Infrastructure Attack)': 0.0029069767441860465,
#  'P(Denmark|Hijacking)': 0.011235955056179775,
#  'P(Denmark|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Denmark|Hostage Taking (Kidnapping))': 0.0,
#  'P(Denmark|Unarmed Assault)': 0.0,
#  'P(Denmark|Unknown)': 0.024128686327077747,
#  'P(East Germany (GDR)|Armed Assault)': 0.00034352456200618345,
#  'P(East Germany (GDR)|Assassination)': 0.0012139605462822458,
#  'P(East Germany (GDR)|Bombing/Explosion)': 0.0014357501794687725,
#  'P(East Germany (GDR)|Facility/Infrastructure Attack)': 0.005087209302325582,
#  'P(East Germany (GDR)|Hijacking)': 0.0,
#  'P(East Germany (GDR)|Hostage Taking (Barricade Incident))': 0.0,
#  'P(East Germany (GDR)|Hostage Taking (Kidnapping))': 0.002061855670103093,
#  'P(East Germany (GDR)|Unarmed Assault)': 0.0,
#  'P(East Germany (GDR)|Unknown)': 0.005361930294906166,
#  'P(Estonia|Armed Assault)': 0.0010305736860185502,
#  'P(Estonia|Assassination)': 0.00030349013657056146,
#  'P(Estonia|Bombing/Explosion)': 0.0010768126346015793,
#  'P(Estonia|Facility/Infrastructure Attack)': 0.0,
#  'P(Estonia|Hijacking)': 0.0,
#  'P(Estonia|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Estonia|Hostage Taking (Kidnapping))': 0.0,
#  'P(Estonia|Unarmed Assault)': 0.0,
#  'P(Estonia|Unknown)': 0.0,
#  'P(Finland|Armed Assault)': 0.0006870491240123669,
#  'P(Finland|Assassination)': 0.0,
#  'P(Finland|Bombing/Explosion)': 0.0003589375448671931,
#  'P(Finland|Facility/Infrastructure Attack)': 0.00436046511627907,
#  'P(Finland|Hijacking)': 0.0,
#  'P(Finland|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Finland|Hostage Taking (Kidnapping))': 0.0,
#  'P(Finland|Unarmed Assault)': 0.0,
#  'P(Finland|Unknown)': 0.0,
#  'P(France|Armed Assault)': 0.0415664720027482,
#  'P(France|Assassination)': 0.049165402124430956,
#  'P(France|Bombing/Explosion)': 0.187275664034458,
#  'P(France|Facility/Infrastructure Attack)': 0.05886627906976744,
#  'P(France|Hijacking)': 0.0449438202247191,
#  'P(France|Hostage Taking (Barricade Incident))': 0.20754716981132076,
#  'P(France|Hostage Taking (Kidnapping))': 0.03505154639175258,
#  'P(France|Unarmed Assault)': 0.08196721311475409,
#  'P(France|Unknown)': 0.13941018766756033,
#  'P(Germany|Armed Assault)': 0.041222947440742015,
#  'P(Germany|Assassination)': 0.007890743550834597,
#  'P(Germany|Bombing/Explosion)': 0.0070890165111270635,
#  'P(Germany|Facility/Infrastructure Attack)': 0.1398982558139535,
#  'P(Germany|Hijacking)': 0.02247191011235955,
#  'P(Germany|Hostage Taking (Barricade Incident))': 0.018867924528301886,
#  'P(Germany|Hostage Taking (Kidnapping))': 0.012371134020618556,
#  'P(Germany|Unarmed Assault)': 0.15846994535519127,
#  'P(Germany|Unknown)': 0.1447721179624665,
#  'P(Greece|Armed Assault)': 0.03813122638268636,
#  'P(Greece|Assassination)': 0.022458270106221548,
#  'P(Greece|Bombing/Explosion)': 0.06191672648959081,
#  'P(Greece|Facility/Infrastructure Attack)': 0.11882267441860465,
#  'P(Greece|Hijacking)': 0.07865168539325842,
#  'P(Greece|Hostage Taking (Barricade Incident))': 0.03773584905660377,
#  'P(Greece|Hostage Taking (Kidnapping))': 0.006185567010309278,
#  'P(Greece|Unarmed Assault)': 0.03825136612021858,
#  'P(Greece|Unknown)': 0.021447721179624665,
#  'P(Hungary|Armed Assault)': 0.0013740982480247338,
#  'P(Hungary|Assassination)': 0.0009104704097116844,
#  'P(Hungary|Bombing/Explosion)': 0.002871500358937545,
#  'P(Hungary|Facility/Infrastructure Attack)': 0.0014534883720930232,
#  'P(Hungary|Hijacking)': 0.0,
#  'P(Hungary|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Hungary|Hostage Taking (Kidnapping))': 0.0,
#  'P(Hungary|Unarmed Assault)': 0.01092896174863388,
#  'P(Hungary|Unknown)': 0.002680965147453083,
#  'P(Iceland|Armed Assault)': 0.0,
#  'P(Iceland|Assassination)': 0.0,
#  'P(Iceland|Bombing/Explosion)': 0.00017946877243359656,
#  'P(Iceland|Facility/Infrastructure Attack)': 0.0003633720930232558,
#  'P(Iceland|Hijacking)': 0.0,
#  'P(Iceland|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Iceland|Hostage Taking (Kidnapping))': 0.0,
#  'P(Iceland|Unarmed Assault)': 0.0,
#  'P(Iceland|Unknown)': 0.002680965147453083,
#  'P(Ireland|Armed Assault)': 0.008244589488148402,
#  'P(Ireland|Assassination)': 0.011532625189681336,
#  'P(Ireland|Bombing/Explosion)': 0.013190954773869347,
#  'P(Ireland|Facility/Infrastructure Attack)': 0.02252906976744186,
#  'P(Ireland|Hijacking)': 0.011235955056179775,
#  'P(Ireland|Hostage Taking (Barricade Incident))': 0.009433962264150943,
#  'P(Ireland|Hostage Taking (Kidnapping))': 0.026804123711340205,
#  'P(Ireland|Unarmed Assault)': 0.02185792349726776,
#  'P(Ireland|Unknown)': 0.0,
#  'P(Italy|Armed Assault)': 0.0769495018893851,
#  'P(Italy|Assassination)': 0.0622154779969651,
#  'P(Italy|Bombing/Explosion)': 0.06030150753768844,
#  'P(Italy|Facility/Infrastructure Attack)': 0.12209302325581395,
#  'P(Italy|Hijacking)': 0.06741573033707865,
#  'P(Italy|Hostage Taking (Barricade Incident))': 0.1792452830188679,
#  'P(Italy|Hostage Taking (Kidnapping))': 0.13195876288659794,
#  'P(Italy|Unarmed Assault)': 0.060109289617486336,
#  'P(Italy|Unknown)': 0.05093833780160858,
#  'P(Kosovo|Armed Assault)': 0.017863277224321537,
#  'P(Kosovo|Assassination)': 0.0030349013657056147,
#  'P(Kosovo|Bombing/Explosion)': 0.009781048097631011,
#  'P(Kosovo|Facility/Infrastructure Attack)': 0.003633720930232558,
#  'P(Kosovo|Hijacking)': 0.0,
#  'P(Kosovo|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Kosovo|Hostage Taking (Kidnapping))': 0.004123711340206186,
#  'P(Kosovo|Unarmed Assault)': 0.01092896174863388,
#  'P(Kosovo|Unknown)': 0.00804289544235925,
#  'P(Latvia|Armed Assault)': 0.00034352456200618345,
#  'P(Latvia|Assassination)': 0.00030349013657056146,
#  'P(Latvia|Bombing/Explosion)': 0.0011665470208183776,
#  'P(Latvia|Facility/Infrastructure Attack)': 0.0003633720930232558,
#  'P(Latvia|Hijacking)': 0.0,
#  'P(Latvia|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Latvia|Hostage Taking (Kidnapping))': 0.0,
#  'P(Latvia|Unarmed Assault)': 0.0,
#  'P(Latvia|Unknown)': 0.0,
#  'P(Lithuania|Armed Assault)': 0.00034352456200618345,
#  'P(Lithuania|Assassination)': 0.00030349013657056146,
#  'P(Lithuania|Bombing/Explosion)': 0.0005384063173007897,
#  'P(Lithuania|Facility/Infrastructure Attack)': 0.0,
#  'P(Lithuania|Hijacking)': 0.0,
#  'P(Lithuania|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Lithuania|Hostage Taking (Kidnapping))': 0.0,
#  'P(Lithuania|Unarmed Assault)': 0.0,
#  'P(Lithuania|Unknown)': 0.0,
#  'P(Luxembourg|Armed Assault)': 0.0,
#  'P(Luxembourg|Assassination)': 0.0006069802731411229,
#  'P(Luxembourg|Bombing/Explosion)': 0.001256281407035176,
#  'P(Luxembourg|Facility/Infrastructure Attack)': 0.0,
#  'P(Luxembourg|Hijacking)': 0.0,
#  'P(Luxembourg|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Luxembourg|Hostage Taking (Kidnapping))': 0.0,
#  'P(Luxembourg|Unarmed Assault)': 0.0,
#  'P(Luxembourg|Unknown)': 0.0,
#  'P(Macedonia|Armed Assault)': 0.01202335967021642,
#  'P(Macedonia|Assassination)': 0.00030349013657056146,
#  'P(Macedonia|Bombing/Explosion)': 0.004486719310839914,
#  'P(Macedonia|Facility/Infrastructure Attack)': 0.005450581395348837,
#  'P(Macedonia|Hijacking)': 0.0,
#  'P(Macedonia|Hostage Taking (Barricade Incident))': 0.018867924528301886,
#  'P(Macedonia|Hostage Taking (Kidnapping))': 0.018556701030927835,
#  'P(Macedonia|Unarmed Assault)': 0.00546448087431694,
#  'P(Macedonia|Unknown)': 0.010723860589812333,
#  'P(Malta|Armed Assault)': 0.00034352456200618345,
#  'P(Malta|Assassination)': 0.0012139605462822458,
#  'P(Malta|Bombing/Explosion)': 0.000987078248384781,
#  'P(Malta|Facility/Infrastructure Attack)': 0.0010901162790697674,
#  'P(Malta|Hijacking)': 0.011235955056179775,
#  'P(Malta|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Malta|Hostage Taking (Kidnapping))': 0.0,
#  'P(Malta|Unarmed Assault)': 0.0,
#  'P(Malta|Unknown)': 0.0,
#  'P(Moldova|Armed Assault)': 0.0017176228100309172,
#  'P(Moldova|Assassination)': 0.00030349013657056146,
#  'P(Moldova|Bombing/Explosion)': 0.0011665470208183776,
#  'P(Moldova|Facility/Infrastructure Attack)': 0.0,
#  'P(Moldova|Hijacking)': 0.0,
#  'P(Moldova|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Moldova|Hostage Taking (Kidnapping))': 0.004123711340206186,
#  'P(Moldova|Unarmed Assault)': 0.0,
#  'P(Moldova|Unknown)': 0.0,
#  'P(Montenegro|Armed Assault)': 0.0,
#  'P(Montenegro|Assassination)': 0.0,
#  'P(Montenegro|Bombing/Explosion)': 0.0003589375448671931,
#  'P(Montenegro|Facility/Infrastructure Attack)': 0.0003633720930232558,
#  'P(Montenegro|Hijacking)': 0.0,
#  'P(Montenegro|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Montenegro|Hostage Taking (Kidnapping))': 0.0,
#  'P(Montenegro|Unarmed Assault)': 0.0,
#  'P(Montenegro|Unknown)': 0.0,
#  'P(Netherlands|Armed Assault)': 0.004465819306080384,
#  'P(Netherlands|Assassination)': 0.0039453717754172985,
#  'P(Netherlands|Bombing/Explosion)': 0.004307250538406317,
#  'P(Netherlands|Facility/Infrastructure Attack)': 0.013444767441860465,
#  'P(Netherlands|Hijacking)': 0.02247191011235955,
#  'P(Netherlands|Hostage Taking (Barricade Incident))': 0.04716981132075472,
#  'P(Netherlands|Hostage Taking (Kidnapping))': 0.0,
#  'P(Netherlands|Unarmed Assault)': 0.0,
#  'P(Netherlands|Unknown)': 0.02680965147453083,
#  'P(Norway|Armed Assault)': 0.0010305736860185502,
#  'P(Norway|Assassination)': 0.00030349013657056146,
#  'P(Norway|Bombing/Explosion)': 0.00026920315865039483,
#  'P(Norway|Facility/Infrastructure Attack)': 0.001816860465116279,
#  'P(Norway|Hijacking)': 0.033707865168539325,
#  'P(Norway|Hostage Taking (Barricade Incident))': 0.009433962264150943,
#  'P(Norway|Hostage Taking (Kidnapping))': 0.0,
#  'P(Norway|Unarmed Assault)': 0.0,
#  'P(Norway|Unknown)': 0.005361930294906166,
#  'P(Poland|Armed Assault)': 0.00034352456200618345,
#  'P(Poland|Assassination)': 0.0015174506828528073,
#  'P(Poland|Bombing/Explosion)': 0.002243359655419957,
#  'P(Poland|Facility/Infrastructure Attack)': 0.0010901162790697674,
#  'P(Poland|Hijacking)': 0.0,
#  'P(Poland|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Poland|Hostage Taking (Kidnapping))': 0.0,
#  'P(Poland|Unarmed Assault)': 0.01092896174863388,
#  'P(Poland|Unknown)': 0.0,
#  'P(Portugal|Armed Assault)': 0.0017176228100309172,
#  'P(Portugal|Assassination)': 0.005462822458270106,
#  'P(Portugal|Bombing/Explosion)': 0.009242641780330223,
#  'P(Portugal|Facility/Infrastructure Attack)': 0.002180232558139535,
#  'P(Portugal|Hijacking)': 0.0,
#  'P(Portugal|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Portugal|Hostage Taking (Kidnapping))': 0.006185567010309278,
#  'P(Portugal|Unarmed Assault)': 0.0,
#  'P(Portugal|Unknown)': 0.010723860589812333,
#  'P(Romania|Armed Assault)': 0.00034352456200618345,
#  'P(Romania|Assassination)': 0.0006069802731411229,
#  'P(Romania|Bombing/Explosion)': 0.00026920315865039483,
#  'P(Romania|Facility/Infrastructure Attack)': 0.0,
#  'P(Romania|Hijacking)': 0.0,
#  'P(Romania|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Romania|Hostage Taking (Kidnapping))': 0.0,
#  'P(Romania|Unarmed Assault)': 0.0,
#  'P(Romania|Unknown)': 0.0,
#  'P(Russia|Armed Assault)': 0.19409137753349365,
#  'P(Russia|Assassination)': 0.0755690440060698,
#  'P(Russia|Bombing/Explosion)': 0.10247666905958364,
#  'P(Russia|Facility/Infrastructure Attack)': 0.021075581395348836,
#  'P(Russia|Hijacking)': 0.19101123595505617,
#  'P(Russia|Hostage Taking (Barricade Incident))': 0.08490566037735849,
#  'P(Russia|Hostage Taking (Kidnapping))': 0.15051546391752577,
#  'P(Russia|Unarmed Assault)': 0.1366120218579235,
#  'P(Russia|Unknown)': 0.05361930294906166,
#  'P(Serbia-Montenegro|Armed Assault)': 0.0010305736860185502,
#  'P(Serbia-Montenegro|Assassination)': 0.0006069802731411229,
#  'P(Serbia-Montenegro|Bombing/Explosion)': 0.00044867193108399136,
#  'P(Serbia-Montenegro|Facility/Infrastructure Attack)': 0.0,
#  'P(Serbia-Montenegro|Hijacking)': 0.0,
#  'P(Serbia-Montenegro|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Serbia-Montenegro|Hostage Taking (Kidnapping))': 0.0,
#  'P(Serbia-Montenegro|Unarmed Assault)': 0.00546448087431694,
#  'P(Serbia-Montenegro|Unknown)': 0.0,
#  'P(Serbia|Armed Assault)': 0.0013740982480247338,
#  'P(Serbia|Assassination)': 0.00030349013657056146,
#  'P(Serbia|Bombing/Explosion)': 0.00044867193108399136,
#  'P(Serbia|Facility/Infrastructure Attack)': 0.0003633720930232558,
#  'P(Serbia|Hijacking)': 0.0,
#  'P(Serbia|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Serbia|Hostage Taking (Kidnapping))': 0.0,
#  'P(Serbia|Unarmed Assault)': 0.0,
#  'P(Serbia|Unknown)': 0.0,
#  'P(Slovak Republic|Armed Assault)': 0.0010305736860185502,
#  'P(Slovak Republic|Assassination)': 0.0,
#  'P(Slovak Republic|Bombing/Explosion)': 0.0011665470208183776,
#  'P(Slovak Republic|Facility/Infrastructure Attack)': 0.0003633720930232558,
#  'P(Slovak Republic|Hijacking)': 0.0,
#  'P(Slovak Republic|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Slovak Republic|Hostage Taking (Kidnapping))': 0.0,
#  'P(Slovak Republic|Unarmed Assault)': 0.00546448087431694,
#  'P(Slovak Republic|Unknown)': 0.0,
#  'P(Slovenia|Armed Assault)': 0.0,
#  'P(Slovenia|Assassination)': 0.00030349013657056146,
#  'P(Slovenia|Bombing/Explosion)': 0.0003589375448671931,
#  'P(Slovenia|Facility/Infrastructure Attack)': 0.0003633720930232558,
#  'P(Slovenia|Hijacking)': 0.0,
#  'P(Slovenia|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Slovenia|Hostage Taking (Kidnapping))': 0.0,
#  'P(Slovenia|Unarmed Assault)': 0.0,
#  'P(Slovenia|Unknown)': 0.0,
#  'P(Soviet Union|Armed Assault)': 0.009275163174166953,
#  'P(Soviet Union|Assassination)': 0.0021244309559939304,
#  'P(Soviet Union|Bombing/Explosion)': 0.0030509691313711416,
#  'P(Soviet Union|Facility/Infrastructure Attack)': 0.0010901162790697674,
#  'P(Soviet Union|Hijacking)': 0.0449438202247191,
#  'P(Soviet Union|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Soviet Union|Hostage Taking (Kidnapping))': 0.006185567010309278,
#  'P(Soviet Union|Unarmed Assault)': 0.0,
#  'P(Soviet Union|Unknown)': 0.0,
#  'P(Spain|Armed Assault)': 0.10202679491583648,
#  'P(Spain|Assassination)': 0.18179059180576632,
#  'P(Spain|Bombing/Explosion)': 0.17067480258435033,
#  'P(Spain|Facility/Infrastructure Attack)': 0.10610465116279069,
#  'P(Spain|Hijacking)': 0.056179775280898875,
#  'P(Spain|Hostage Taking (Barricade Incident))': 0.10377358490566038,
#  'P(Spain|Hostage Taking (Kidnapping))': 0.1958762886597938,
#  'P(Spain|Unarmed Assault)': 0.01092896174863388,
#  'P(Spain|Unknown)': 0.1126005361930295,
#  'P(Sweden|Armed Assault)': 0.004122294744074201,
#  'P(Sweden|Assassination)': 0.0021244309559939304,
#  'P(Sweden|Bombing/Explosion)': 0.00314070351758794,
#  'P(Sweden|Facility/Infrastructure Attack)': 0.02071220930232558,
#  'P(Sweden|Hijacking)': 0.011235955056179775,
#  'P(Sweden|Hostage Taking (Barricade Incident))': 0.009433962264150943,
#  'P(Sweden|Hostage Taking (Kidnapping))': 0.0,
#  'P(Sweden|Unarmed Assault)': 0.00546448087431694,
#  'P(Sweden|Unknown)': 0.010723860589812333,
#  'P(Switzerland|Armed Assault)': 0.0024046719340432843,
#  'P(Switzerland|Assassination)': 0.0039453717754172985,
#  'P(Switzerland|Bombing/Explosion)': 0.00574300071787509,
#  'P(Switzerland|Facility/Infrastructure Attack)': 0.005450581395348837,
#  'P(Switzerland|Hijacking)': 0.033707865168539325,
#  'P(Switzerland|Hostage Taking (Barricade Incident))': 0.018867924528301886,
#  'P(Switzerland|Hostage Taking (Kidnapping))': 0.004123711340206186,
#  'P(Switzerland|Unarmed Assault)': 0.0,
#  'P(Switzerland|Unknown)': 0.005361930294906166,
#  'P(Ukraine|Armed Assault)': 0.1370663002404672,
#  'P(Ukraine|Assassination)': 0.010622154779969651,
#  'P(Ukraine|Bombing/Explosion)': 0.08210696338837042,
#  'P(Ukraine|Facility/Infrastructure Attack)': 0.036337209302325583,
#  'P(Ukraine|Hijacking)': 0.011235955056179775,
#  'P(Ukraine|Hostage Taking (Barricade Incident))': 0.07547169811320754,
#  'P(Ukraine|Hostage Taking (Kidnapping))': 0.24123711340206186,
#  'P(Ukraine|Unarmed Assault)': 0.04371584699453552,
#  'P(Ukraine|Unknown)': 0.17962466487935658,
#  'P(United Kingdom|Armed Assault)': 0.21779457231192031,
#  'P(United Kingdom|Assassination)': 0.4986342943854325,
#  'P(United Kingdom|Bombing/Explosion)': 0.18413496051687006,
#  'P(United Kingdom|Facility/Infrastructure Attack)': 0.22056686046511628,
#  'P(United Kingdom|Hijacking)': 0.20224719101123595,
#  'P(United Kingdom|Hostage Taking (Barricade Incident))': 0.1320754716981132,
#  'P(United Kingdom|Hostage Taking (Kidnapping))': 0.10721649484536082,
#  'P(United Kingdom|Unarmed Assault)': 0.2185792349726776,
#  'P(United Kingdom|Unknown)': 0.10187667560321716,
#  'P(Vatican City|Armed Assault)': 0.0,
#  'P(Vatican City|Assassination)': 0.00030349013657056146,
#  'P(Vatican City|Bombing/Explosion)': 0.0,
#  'P(Vatican City|Facility/Infrastructure Attack)': 0.0,
#  'P(Vatican City|Hijacking)': 0.0,
#  'P(Vatican City|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Vatican City|Hostage Taking (Kidnapping))': 0.0,
#  'P(Vatican City|Unarmed Assault)': 0.0,
#  'P(Vatican City|Unknown)': 0.0,
#  'P(West Germany (FRG)|Armed Assault)': 0.01580212985228444,
#  'P(West Germany (FRG)|Assassination)': 0.013353566009104704,
#  'P(West Germany (FRG)|Bombing/Explosion)': 0.025574300071787508,
#  'P(West Germany (FRG)|Facility/Infrastructure Attack)': 0.052688953488372096,
#  'P(West Germany (FRG)|Hijacking)': 0.0449438202247191,
#  'P(West Germany (FRG)|Hostage Taking (Barricade Incident))': 0.018867924528301886,
#  'P(West Germany (FRG)|Hostage Taking (Kidnapping))': 0.012371134020618556,
#  'P(West Germany (FRG)|Unarmed Assault)': 0.01639344262295082,
#  'P(West Germany (FRG)|Unknown)': 0.0160857908847185,
#  'P(Yugoslavia|Armed Assault)': 0.03160425970456888,
#  'P(Yugoslavia|Assassination)': 0.006373292867981791,
#  'P(Yugoslavia|Bombing/Explosion)': 0.006371141421392678,
#  'P(Yugoslavia|Facility/Infrastructure Attack)': 0.001816860465116279,
#  'P(Yugoslavia|Hijacking)': 0.011235955056179775,
#  'P(Yugoslavia|Hostage Taking (Barricade Incident))': 0.0,
#  'P(Yugoslavia|Hostage Taking (Kidnapping))': 0.010309278350515464,
#  'P(Yugoslavia|Unarmed Assault)': 0.0,
#  'P(Yugoslavia|Unknown)': 0.021447721179624665}

# %%
dt_novo = dt[dt.attacktype1_txt == y]
